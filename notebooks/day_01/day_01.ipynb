# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# A global community collaborating to build open-source Nextflow components and pipelines

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# Based on the Pipeline page: 139
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?
#
# Yes, for example the nf-core/meerpipe which is a astronomy pipeline.

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# The idea is to process large volumes of raw biological data, such as DNA or RNA sequences. A pipeline is built using automated, systematic software and/or algorithmic steps to produce interpretable output. This ensures consistent and reproducible results.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# Nf-core tries to follow the FAIR principles. Thes are guidelines to improve the Findability, Accessibility, Interoperability, and Reuse of digital datasets. Therefore Nf-core is a main driver to achieve these goals.

# %% [markdown]
# 6. What are the main features of nf-core pipelines?
# - extensive documentation
# - stable releases
# - open source: All nf-core code is licensed under the MIT license
# - CI testing
# - run anywhere
# - packaged software

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %% [markdown]
# nf-core/differentialabundance

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd

# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!
# Out:
# /Users/leoniewehnert/pCloud Drive/Master/Semester 4/Nextflow_Prak/computational-workflows-2025/notebooks/day_01

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)

#!nextflow run nf-core/differentialabundance

# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [nostalgic_goldberg] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : nostalgic_goldberg
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/leoniewehnert/.nextflow/assets/nf-core/differentialabundance
#   userName                    : leoniewehnert
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (4)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [89/aa6f33] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 1 of 2
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 1 of 2
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 0 of 1
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a08cc4] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a08cc4] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a08cc4] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a08cc4] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/cc8082] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/cc8082] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/cc8082] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/cc8082] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [da/5034db] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [da/5034db] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [da/5034db] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f9/997e27] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f9/997e27] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f9/997e27] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f9/997e27] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [5c/6f8310] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [94/7eab38] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [5c/6f8310] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [94/7eab38] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [5c/6f8310] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [94/7eab38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [93/a6a371] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [5c/6f8310] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [94/7eab38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [93/a6a371] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [f3/f98be6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [e9/430b57] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [e1/100c84] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [a5/cfa19d] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [5a/5bc517] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [2c/900710] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [f2/3e1d11] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ba/9d060a] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [19/b7e8ae] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [77/7e3847] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [5c/6f8310] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [aa/75fb79] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f2/564aa3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [39/cefdaa] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [94/7eab38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [93/a6a371] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 14:00:45
# Duration    : 11m 33s
# CPU hours   : 0.2
# Succeeded   : 21

# %%
# repeat the run. What did change?
# First run: Duration    : 11m 33, CPU hours   : 0.2, Succeeded   : 21
# Second run: Duration    : 10m 30s, CPU hours   : 0.2, Succeeded   : 21
# hashes on left side, the order changed

# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [desperate_bell] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : desperate_bell
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/leoniewehnert/.nextflow/assets/nf-core/differentialabundance
#   userName                    : leoniewehnert
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (2)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [42/26893d] NFC…Cherry_hND6_sample_number) | 0 of 2
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [42/26893d] NFC…Cherry_hND6_sample_number) | 0 of 2
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 0 of 1
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 0 of 1
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [78/d76789] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [78/d76789] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [78/d76789] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [03/b24410] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [03/b24410] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [03/b24410] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [03/b24410] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d4/8fd310] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [03/b24410] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d4/8fd310] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d4/8fd310] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d4/8fd310] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f9/868a41] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 0 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f9/868a41] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [98/1f8d4c] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [98/1f8d4c] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ed/2a563a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [98/1f8d4c] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 14:12:35
# Duration    : 10m 30s
# CPU hours   : 0.2
# Succeeded   : 21

# %%
# now set -resume to the command. What did change? 
# the time changed it is way faster, around 1 min
# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker -resume --outdir test
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [silly_babbage] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : silly_babbage
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/leoniewehnert/.nextflow/assets/nf-core/differentialabundance
#   userName                    : leoniewehnert
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6d/b07b05] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f9/868a41] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6d/b07b05] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6d/b07b05] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [98/1f8d4c] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6d/b07b05] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [98/1f8d4c] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [b0/aa409d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [1f/72558c] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [9e/a91bd2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [8f/13356f] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e6/cf6723] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [04/a1c7a1] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [24/2280ee] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [c1/b73525] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [c1/1f4f3d] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6f/c8afd9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/1db225] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [90/0bbc3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c6/0fb864] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [6d/b07b05] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [4d/55584a] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [98/1f8d4c] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# The hash values at the left side are the same! This makes the computation way faster!
#
# Nextflow maintains a cache of all previously run processes in the work/ directory. With -resume, only new or modified tasks run.
# Identical tasks are skipped and their cached outputs are re-linked, which is almost instantaneous.

# %%
# delete the work directory and run the pipeline again using -resume. What did change?
# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker -resume --outdir test
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [gloomy_ptolemy] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : gloomy_ptolemy
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/leoniewehnert/Desktop/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/leoniewehnert/.nextflow/assets/nf-core/differentialabundance
#   userName                    : leoniewehnert
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (4)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [24/ec0635] NFC…Cherry_hND6_sample_number) | 0 of 2
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [ad/b174ba] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 0 of 1
# [ad/b174ba] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [76/9cffe3] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [76/9cffe3] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [76/9cffe3] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [76/9cffe3] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [76/9cffe3] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [76/9cffe3] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [dd/b4c94a] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [68/8e861c] NFC…Cherry_hND6_sample_number) | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [68/8e861c] NFC…Cherry_hND6_sample_number) | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [68/8e861c] NFC…Cherry_hND6_sample_number) | 1 of 2
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fc/729545] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fc/729545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fc/729545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [45/1bd295] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fc/729545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [45/1bd295] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [68/7506ff] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [ad/12e84d] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [c6/f8d5c6] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d9/dacb31] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [a4/100f3d] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [c2/0ffb34] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [a3/79fe76] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [f5/1dc287] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f9/b34667] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9c/dac3bd] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [a0/12280c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [52/aa946b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [80/fd1569] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [b4/e3cad6] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fc/729545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [45/1bd295] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 16:47:35
# Duration    : 10m 39s
# CPU hours   : 0.2
# Succeeded   : 21

# %% [markdown]
# What changed? <br>
# The runtime increases again, the order of the hashes is new as well. Every process will be recomputed from scratch, even with -resume, because there is nothing to reuse.
# It behaves just like a fresh run.

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?
# The idea is to do a statistical comparison of feature abundances across groups to identify significant changes.

# %% [markdown]
# Give the most important plots from the report:
# - (MA plots (before / after shrinkage): Show the relationship between log₂ fold change and mean abundance. They help to evaluate whether normalization worked correctly and whether the statistical assumptions of the model are reasonable)
# - Preprocesing: Boxplots of different samples/treatments, they provide an overview of the distribution of abundances across samples. They are useful for spotting outliers, distribution shifts, or normalization issues.
# - Data Reduction: Principal Component Analysis (PCA), highlights the major axes of variation among samples. This allows to check whether samples cluster according to biological groups, or whether there are batch effects or other artifacts.
# - Final Analyis: Volcano plots display log₂ fold change versus –log₁₀ p-value, indicating which features (genes/taxa) are significantly up- or down-regulated between contrasts.
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
